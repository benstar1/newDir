# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sbn

# %%
datafile=pd.read_csv("recensTKD2020.csv", sep=";", encoding="iso8859_15", header=0)

# %%
col=pd.read_csv("recens_header.csv", sep="r")
global columns
for i in col:
    columns=i
columns
# Out:
# 'NOM;PRENOMS;DATE_NAISS;LIEU_NAISS;SEXE;NATIONALITE;PROFESSION;TEL1;TEL2;EMAIL;ADRESSE;DEPARTEMENT;COMMUNES;ARRONDISSEMENT;ASSOCIATION/CLUB;STATUT_TKD;GRADE_FBTAE;GRADE_KUKKIWON;NUMERO_KUKKIWON'

# %% [markdown]
# columns

# %%
columns=columns.split(';')

# %%
df=pd.DataFrame(datafile,columns=columns)

# %%
df
# Out:
#                  NOM           PRENOMS  DATE_NAISS               LIEU_NAISS  \
# 0    FLEURIC NOUGLOI      Nael Steffer  11/05/2007                  Parakou
# 1        GOUDOU BIDA             Dylan  04/06/2004                  Cotonou
# 2            JOHNSON  BENTSIWA BENALIE  06/02/2008                  COTONOU
# 3            JOHNSON    EMISSAH LITSIE  15/02/2013                  COTONOU
# 4              EGLOH            Wisdom  18/06/2013                  Cotonou
# ..               ...               ...         ...                      ...
# 388         de SOUZA            Bergis  24/01/1992                   Abomey
# 389           ALIDJI    Dossou Delphin  02/11/1992  Daloa ( côte d'Ivoire )
# 390           TOSSOU    Minankpon Éric  30/10/1986                  SAVALOU
# 391         CHOGNIKA             Eudes  12/01/1966                  Bohicon
# 392          JOHNSON   MAHOUENA BENTSI  13/02/1980                  COTONOU
#
# ...

# %%
percSexe=df.groupby('SEXE').agg({'SEXE' : 'count'}).apply(lambda x: 100 * x/df['SEXE'].count())
percSexe
#tot=df['SEXE'].count()
#tot
# Out:
#            SEXE
# SEXE
# F     23.918575
# M     76.081425

# %%
percNationality=df.groupby('NATIONALITE').agg({'NATIONALITE':'count'}).apply(lambda x: 100 * x/df['NATIONALITE'].count())
percNationality
# Out:
#              NATIONALITE
# NATIONALITE
# Bénin          97.455471
# Gabon           0.254453
# Mali            0.254453
# Niger           1.017812
# Pakistan        0.254453
# Togo            0.763359

# %%
percProf=df.groupby('PROFESSION').agg({'PROFESSION':'count'}).apply(lambda x: 100 *x/df['PROFESSION'].count())
percProf.shape
pd.set_option('display.max_rows', percProf.shape[0]+1)
percProf
# Out:
#                                                     PROFESSION
# PROFESSION
# Administrateur civil                                  0.254453
# Administrateur des services fiscaux et des serv...    0.254453
# Administrateur, gérant d'entreprise                   0.508906
# Agent commercial                                      0.508906
# Agent de police                                       0.254453
# Agronome                                              1.017812
# Aide vendeur                                          0.508906
# Arbitre, sport                                        0.254453
# Assistant de santé, attaché de santé                  0.254453
# Assistant pharmacien                                  0.254453
# Athlète professionnel (coureur, footballeur, bo...    1.272265
# Biologiste                                            0.254453
# Cadre comptable                                       0.763359
# Chercheur (attaché de recherches, chargé de rec...    0.254453
# ...

# %%
percSexe.to_csv("percSexe.csv", sep=";")
percProf.to_csv('percProf.csv', sep=";")
percNationality.to_csv('percNationality.csv', sep=";")

# %%
df.describe()
# Out:
#             NOM   PRENOMS  DATE_NAISS LIEU_NAISS SEXE NATIONALITE PROFESSION  \
# count       393       393         393        392  393         393        393
# unique      253       384         370         74    2           6         61
# top     HOUNGAN  Youssouf  01/01/1996    Cotonou    M       Bénin      Elève
# freq          7         3           3        161  299         383        249
#
#             TEL1              TEL2                       EMAIL  ADRESSE  \
# count        393               224                         269      321
# unique       233               120                         154      184
# top     62962697  (00229) 66959321  constandohou2016@gmail.com  Tokpota
# freq          37                36                          39       20
#
#        DEPARTEMENT       COMMUNES      ARRONDISSEMENT ASSOCIATION/CLUB  \
# count          393            393                 356              393
# unique           8             14                  27              122
# ...

# %%
df.dtypes
# Out:
# NOM                 object
# PRENOMS             object
# DATE_NAISS          object
# LIEU_NAISS          object
# SEXE                object
# NATIONALITE         object
# PROFESSION          object
# TEL1                object
# TEL2                object
# EMAIL               object
# ADRESSE             object
# DEPARTEMENT         object
# COMMUNES            object
# ARRONDISSEMENT      object
# ASSOCIATION/CLUB    object
# STATUT_TKD          object
# GRADE_FBTAE         object
# GRADE_KUKKIWON      object
# NUMERO_KUKKIWON     object
# dtype: object

# %%
df['DATE_NAISS']=pd.to_datetime(df['DATE_NAISS'])

# %%
df.dtypes
# Out:
# NOM                         object
# PRENOMS                     object
# DATE_NAISS          datetime64[ns]
# LIEU_NAISS                  object
# SEXE                        object
# NATIONALITE                 object
# PROFESSION                  object
# TEL1                        object
# TEL2                        object
# EMAIL                       object
# ADRESSE                     object
# DEPARTEMENT                 object
# COMMUNES                    object
# ARRONDISSEMENT              object
# ASSOCIATION/CLUB            object
# STATUT_TKD                  object
# GRADE_FBTAE                 object
# GRADE_KUKKIWON              object
# NUMERO_KUKKIWON             object
# dtype: object

# %%
import datetime as dt
pd.to_datetime(df['DATE_NAISS'])
# Out:
# 0     2007-11-05
# 1     2004-04-06
# 2     2008-06-02
# 3     2013-02-15
# 4     2013-06-18
#          ...
# 388   1992-01-24
# 389   1992-02-11
# 390   1986-10-30
# 391   1966-12-01
# 392   1980-02-13
# Name: DATE_NAISS, Length: 393, dtype: datetime64[ns]

# %%
ages=np.array(range(0,len(df['DATE_NAISS'])))
j=0
for i in df['DATE_NAISS']:    
    fin= pd.to_datetime('today')
    age = len(pd.date_range(start=i, end=fin, freq='Y')) 
    ages[j]=age
    j+=1

# %%
ageDf = pd.DataFrame(ages, columns=['AGE'])

# %%
t=np.timedelta64(100, 'Y')
pd.to_datetime('today') - t
# Out:
# Timestamp('1920-07-13 17:06:12.363638')

# %%
df = pd.concat([df, ageDf], axis=1)

# %%
df.groupby('AGE').agg(['min', 'max','count'])
# Out:
#               NOM                                                  PRENOMS  \
#               min                max count                             min
# AGE
# 0        da COSTA           da COSTA     1                  Marius Florent
# 2           DOHOU              DOHOU     1                       Eva Chloé
# 3          ALIDOU             TEGAOU     4                Abdoul Ahad Wèri
# 4            ADAM             TOSSOU     5           JOSHUA ETHAN MAHUGNON
# 5          HINNOU               TOKO     6             Akidé Steve Estache
# 6          ADOGLO            YAYA O.    10                       Ayath-lah
# 7       AHANDESSI           TOKANNOU    18                   Abdoul Ganiou
# 8    AHOUANOUAGAN              SALIA    20                          Abdala
# 9     ACCROMBESSI           YOUSSOUF    22                            Adle
# 10      ABOUBACAR           TOKANNOU    23                Aboubacari sidik
# ...

# %%
percSexe=df.groupby(['DEPARTEMENT','SEXE']).agg({'SEXE' : 'count'})

# %%
percSexe
# Out:
#                   SEXE
# DEPARTEMENT SEXE
# ATACORA     F        2
#             M       23
# ATLANTIQUE  F       25
#             M       86
# BORGOU      F        2
#             M       19
# DONGA       F       17
#             M       43
# LITTORAL    F       21
#             M       84
# OUEME       F       27
#             M       39
# PLATEAU     M        2
# ZOU         M        3

# %%
from sklearn.datasets import load_wine
wines=load_wine()

# %%
dir(wines)
# Out:
# ['DESCR', 'data', 'feature_names', 'target', 'target_names']

# %%
wine_data=wines.data
columns=np.array(wines.feature_names)

# %%
wine_data.shape, columns.shape
# Out:
# ((178, 13), (13,))

# %%
wine_df=pd.DataFrame(wine_data, columns=columns)

# %%
wine_df.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# dtype: object

# %%
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
wine_df.d
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-8204b5c8504f> in <module>
# ----> 1 wine_df.data
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
import matplotlib.pylab as plt
df.plot.scatter('AGE','SEXE')

# %%
df
# Out:
#                  NOM           PRENOMS DATE_NAISS               LIEU_NAISS  \
# 0    FLEURIC NOUGLOI      Nael Steffer 2007-11-05                  Parakou
# 1        GOUDOU BIDA             Dylan 2004-04-06                  Cotonou
# 2            JOHNSON  BENTSIWA BENALIE 2008-06-02                  COTONOU
# 3            JOHNSON    EMISSAH LITSIE 2013-02-15                  COTONOU
# 4              EGLOH            Wisdom 2013-06-18                  Cotonou
# ..               ...               ...        ...                      ...
# 388         de SOUZA            Bergis 1992-01-24                   Abomey
# 389           ALIDJI    Dossou Delphin 1992-02-11  Daloa ( côte d'Ivoire )
# 390           TOSSOU    Minankpon Éric 1986-10-30                  SAVALOU
# 391         CHOGNIKA             Eudes 1966-12-01                  Bohicon
# 392          JOHNSON   MAHOUENA BENTSI 1980-02-13                  COTONOU
#
# ...

# %%
percSexe.plot.pie(y='SEXE',figsize=(12, 12),autopct='%1.2f%%', startangle=90)

# %%
df.dtypes
# Out:
# NOM                         object
# PRENOMS                     object
# DATE_NAISS          datetime64[ns]
# LIEU_NAISS                  object
# SEXE                        object
# NATIONALITE                 object
# PROFESSION                  object
# TEL1                        object
# TEL2                        object
# EMAIL                       object
# ADRESSE                     object
# DEPARTEMENT                 object
# COMMUNES                    object
# ARRONDISSEMENT              object
# ASSOCIATION/CLUB            object
# STATUT_TKD                  object
# GRADE_FBTAE                 object
# GRADE_KUKKIWON              object
# NUMERO_KUKKIWON             object
# AGE                          int32
# dtype: object

# %%
df.plot.scatter('AGE','SEXE')

# %%
df['GRADE_KUKKIWON'][389]='CN2'
# Out:
# C:\Users\Ben\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                  NOM           PRENOMS DATE_NAISS               LIEU_NAISS  \
# 0    FLEURIC NOUGLOI      Nael Steffer 2007-11-05                  Parakou
# 1        GOUDOU BIDA             Dylan 2004-04-06                  Cotonou
# 2            JOHNSON  BENTSIWA BENALIE 2008-06-02                  COTONOU
# 3            JOHNSON    EMISSAH LITSIE 2013-02-15                  COTONOU
# 4              EGLOH            Wisdom 2013-06-18                  Cotonou
# ..               ...               ...        ...                      ...
# 388         de SOUZA            Bergis 1992-01-24                   Abomey
# 389           ALIDJI    Dossou Delphin 1992-02-11  Daloa ( côte d'Ivoire )
# 390           TOSSOU    Minankpon Éric 1986-10-30                  SAVALOU
# 391         CHOGNIKA             Eudes 1966-12-01                  Bohicon
# 392          JOHNSON   MAHOUENA BENTSI 1980-02-13                  COTONOU
#
# ...

# %%
df.sort_values('GRADE_FBTAE').plot.scatter('SEXE','GRADE_FBTAE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-10861462c0ac> in <module>
# ----> 1 df.sort_values('GRADE_FBTAE').plot.scatter('SEXE','GRADE_FBTAE')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1497             ...                       colormap='viridis')
#    1498         """
# -> 1499         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1500
#    1501     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
# ...

# %%
df_F = df[df['SEXE'] == 'F']
df_M = df[df['SEXE'] == 'M']

# %%
df_M_grade = df_M.groupby('GRADE_FBTAE').agg({'SEXE':'count'})
df_M_grade.columns = ['SEXEm']
df_M_grade

df_F_grade = df_F.groupby('GRADE_FBTAE').agg({'SEXE':'count'})
df_F_grade.columns = ['SEXEf']
df_F_grade
# Out:
#              SEXEf
# GRADE_FBTAE
# 10E KEUP         4
# 11E KEUP         7
# 12E KEUP        14
# 1E KEUP          4
# 2E KEUP          4
# 3E KEUP          2
# 4E KEUP          6
# 5E KEUP          7
# 6E KEUP          2
# 7E KEUP          7
# 8E KEUP          8
# 9E KEUP         18
# CN1              4
# CN2              4
# CN3              2
# CN4              1

# %%
df_MF_grade = pd.concat([df_M_grade, df_F_grade], axis=1)
df_MF_grade
# Out:
#           SEXEm  SEXEf
# 10E KEUP     11    4.0
# 11E KEUP     13    7.0
# 12E KEUP     16   14.0
# 1E KEUP      16    4.0
# 2E KEUP      12    4.0
# 3E KEUP      19    2.0
# 4E KEUP      12    6.0
# 5E KEUP       8    7.0
# 6E KEUP      15    2.0
# 7E KEUP      18    7.0
# 8E KEUP      34    8.0
# 9E KEUP      39   18.0
# CN1          20    4.0
# CN2          27    4.0
# CN3          16    2.0
# CN4           9    1.0
# CN5           8    NaN
# CN6           1    NaN
# CN8           1    NaN

# %%
df_MF_grade.plot.pie(y='SEXEf',figsize=(12, 12), autopct='%0.0f')

# %%
df.dtypes
# Out:
# NOM                         object
# PRENOMS                     object
# DATE_NAISS          datetime64[ns]
# LIEU_NAISS                  object
# SEXE                        object
# NATIONALITE                 object
# PROFESSION                  object
# TEL1                        object
# TEL2                        object
# EMAIL                       object
# ADRESSE                     object
# DEPARTEMENT                 object
# COMMUNES                    object
# ARRONDISSEMENT              object
# ASSOCIATION/CLUB            object
# STATUT_TKD                  object
# GRADE_FBTAE                 object
# GRADE_KUKKIWON              object
# NUMERO_KUKKIWON             object
# AGE                          int32
# dtype: object

# %%
df_nbre_com = df.groupby('COMMUNES').agg({'AGE':'count'})
df_nbre_com
# Out:
#                  AGE
# COMMUNES
# ABOMEY-CALAVI    111
# AKPRO-MISSERETE    2
# BASSILA           18
# BOHICON            3
# COTONOU          107
# DJOUGOU           42
# IFANGNI            2
# NATITINGOU        22
# NIKKI              1
# OUASSA-PEHUNCO     1
# PARAKOU           19
# PORTO-NOVO        63
# SEME-PODJI         1
# TCHAOUROU          1

# %%
df_nbre_com.plot.pie(subplots=True, autopct='%0.0f%%', figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000028DECEC2308>],
#       dtype=object)

# %%
df_nbre_com.plot.bar()

# %%
df_nbre_prof=df.groupby('PROFESSION').agg({'PROFESSION':'count'})
df_nbre_prof = df_nbre_prof[df_nbre_prof['PROFESSION'] > 2]
df_nbre_prof
# Out:
#                                                     PROFESSION
# PROFESSION
# Agronome                                                     4
# Athlète professionnel (coureur, footballeur, bo...           5
# Cadre comptable                                              3
# Comptable                                                    3
# Elève                                                      249
# Entraîneur                                                   6
# Entrepreneur                                                 3
# Etudiant                                                    34
# Informaticien                                                8
# Juriste                                                      6
# Maçon - tâcheron                                             3
# Médecin                                                      5
# Professeur d'enseignement secondaire                         4
# Vendeur                                                      5

# %%
from matplotlib import pyplot as plt
df_nbre_prof.plot.pie(figsize=(10,10), autopct='%0.0f%%', subplots=True, legend={'loc':'left'})
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000028DF050A9C8>],
#       dtype=object)

# %%
df_nbre_prof.plot.bar(title='NBre pratiquants par cat. socioprof')

# %%
df.dtypes
# Out:
# NOM                         object
# PRENOMS                     object
# DATE_NAISS          datetime64[ns]
# LIEU_NAISS                  object
# SEXE                        object
# NATIONALITE                 object
# PROFESSION                  object
# TEL1                        object
# TEL2                        object
# EMAIL                       object
# ADRESSE                     object
# DEPARTEMENT                 object
# COMMUNES                    object
# ARRONDISSEMENT              object
# ASSOCIATION/CLUB            object
# STATUT_TKD                  object
# GRADE_FBTAE                 object
# GRADE_KUKKIWON              object
# NUMERO_KUKKIWON             object
# AGE                          int32
# dtype: object

# %%
# Select all lines from columns 4 and 16
df_sexe_grade = df.iloc[:,[4,16]]
df_sexe_grade
# Out:
#     SEXE GRADE_FBTAE
# 0      M     6E KEUP
# 1      M     4E KEUP
# 2      F    12E KEUP
# 3      F    12E KEUP
# 4      M    10E KEUP
# ..   ...         ...
# 388    M         CN1
# 389    M         NaN
# 390    M         NaN
# 391    M         NaN
# 392    M         NaN
#
# [393 rows x 2 columns]

# %%
j=0
for i in df_sexe_grade['GRADE_FBTAE']:
    if df_sexe_grade['GRADE_FBTAE'][j]=='NaN':
        df_sexe_grade['GRADE_FBTAE'][j] = -1
    elif df_sexe_grade['GRADE_FBTAE'][j]=='CN8':
        df_sexe_grade['GRADE_FBTAE'][j] = 20
    j+=1

# %%
df_sexe_grade
# Out:
#     SEXE GRADE_FBTAE
# 0      1           6
# 1      1           4
# 2      0          12
# 3      0          12
# 4      1          10
# ..   ...         ...
# 388    1          13
# 389    1          -1
# 390    1          -1
# 391    1          -1
# 392    1          -1
#
# [393 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

kmeans=KMeans(n_clusters=3).fit(df_sexe_grade)
centroids = kmeans.cluster_centers_
print (centroids)

    plt.scatter(df_sexe_grade['SEXE'], df_sexe_grade['GRADE_FBTAE'],c=kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:,0], centroids[:,1], c='red', s=50)
# Out:
#   File "<ipython-input-83-fb8cbdeb353f>", line 7
#     plt.scatter(df_sexe_grade['AGE'], df_sexe_grade['GRADE_FBTAE'],c=kmeans.labels_.astype(float), s=50, alpha=0.5)
#     ^
# IndentationError: unexpected indent

# %%
df_sexe_grade = pd.concat([df_sexe_grade, df['AGE']], axis=1)

# %%
df_sexe_grade = pd.concat([df_sexe_grade['AGE'], df_sexe_grade['GRADE_FBTAE']], axis=1)

# %%
df_sexe_grade
# Out:
#      AGE GRADE_FBTAE
# 0     13           6
# 1     16           4
# 2     12          12
# 3      7          12
# 4      7          10
# ..   ...         ...
# 388   28          13
# 389   28          -1
# 390   34          -1
# 391   54          -1
# 392   40          -1
#
# [393 rows x 2 columns]

# %%
kmeans=KMeans(n_clusters=4).fit(df_sexe_grade)
centroids = kmeans.cluster_centers_
print (centroids)

plt.scatter(df_sexe_grade['AGE'], df_sexe_grade['GRADE_FBTAE'],c=kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:,0], centroids[:,1], c='red', s=50)
# Out:
# [[28.2         9.7       ]
#  [ 8.265625    9.5625    ]
#  [48.02380952 13.80952381]
#  [14.98601399  6.18181818]]

# %% [markdown]
# <a href=https://www.cognitiveclass.ai>Cognitive Class</a>

# %% [markdown]
# # Header 1

# %% [markdown]
# # Header 2
